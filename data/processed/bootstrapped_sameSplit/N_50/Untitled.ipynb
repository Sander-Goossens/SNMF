# %%
import os
import pandas as pd
import numpy as np
import pickle as pkl

# %%
temp = pkl.load(open('/Users/sande/PycharmProjects/msc-thesis-2122-sandergoossens/data/processed/bootstrapped_sameSplit/N_50/train_1.pkl','rb'))

temp
# Out:
#               A[C>A]A   A[C>A]C   A[C>A]G   A[C>A]T   A[C>G]A   A[C>G]C  \
# 0            0.026484  0.017352  0.006393  0.024658  0.007306  0.009132
# 1            0.047970  0.003690  0.011070  0.007380  0.011070  0.003690
# 2            0.040590  0.003690  0.011070  0.014760  0.007380  0.000000
# 3            0.023744  0.017352  0.008219  0.012785  0.009132  0.012785
# 4            0.047970  0.000000  0.007380  0.014760  0.007380  0.000000
# ...               ...       ...       ...       ...       ...       ...
# MSH2_120_s2  0.011017  0.002119  0.000424  0.011017  0.002119  0.001271
# MSH6_3_s8    0.006762  0.003005  0.001503  0.008640  0.000751  0.001127
# MSH6_3_s4    0.003407  0.005679  0.000000  0.006246  0.001704  0.001136
# PMS1_130_s2  0.036011  0.002770  0.000000  0.016620  0.000000  0.002770
# PMS2_170_s2  0.012963  0.003086  0.000617  0.010494  0.003086  0.003086
#
#               A[C>G]G   A[C>G]T   A[C>T]A   A[C>T]C  ...   T[T>G]G   T[T>G]T  \
# ...

# %%
os.getcwd()
# Out:
# '/Users/sande/PycharmProjects/msc-thesis-2122-sandergoossens/data/processed/bootstrapped_sameSplit/N_50'
